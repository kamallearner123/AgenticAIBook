# %%
# Module?: (Library)ch os,
# Variable ?: char1, char2, road1, object1, etc.....
# Function ?
# Conidtion ?
# Loop ?
# Operations ?

# %%
# Module 
import os # Library with functions like getcwd()
print(os.getcwd()) # Current working Directory
# Out:
# /Users/kamalmukiri/Documents/1.GitHub/acl-agenctic-ai-book/AgenticAIBook/Practice/Day_01

# %%
# Variable
Paragraph1 = '''
    Hi, abhinav has scored 90% in maths.
    It is top in the class.
'''
Paragraph2 = '''
    Hi, abhinav has scored 70% in maths.
    It is in top 10 in the class.
'''

# Paragraph1 ??
# String

a = 10
a = a+10
# a? : Integer: Range: 0 to 100000000000000

b = 1.1
# b? : Floating point number: 0.1 to 100000.112234

c = True # (Boolean)
# c? : Boolean: True or False

d = "Hello"
e = '''
    Hi Good morning,
    How was yesterday's party?
'''
# d? : String: "hi", "welcome", "fdsafdsfdsafdsafdsaf fsafdsafds"
print(e)
print(d)
print(a)
# Out:
#     Hi Good morning,
#     How was yesterday's party?
#
# Hello
# 20

# %%
# Function
# def function_name(Argument1, Argument2, ....):
#          return val
def calculate(a, b):
    result = a**2 + b**2 + 2*a*b # 4+9+12
    return result


a = 2
b = 3
output = calculate(a,b) # Calling function 'calculate' and passing arguments a,b
print(output)
# Out:
# 25

# %%
# variable = value
name = "Abhinav"
age = 12
address = "Chennai, India"

# Updating
name = name.upper()
# Refering
print(name)
age = age+1
# deleting a variable  from the scope
del name

print(name)
# Out:
# ABHINAV
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 14
#      11 # deleting a variable  from the scope
#      12 del name
# ---> 14 print(name)
#
# NameError: name 'name' is not defined

# %%
charecter1 = {"Name": "Fanta",
             "Color": "Orange",
             "Capabilities":["Run", "Fight"],
             "Action": "Running"
            } # 1024 bytes = 1KB

charecter2 = {"Name": "Zeno",
             "Color": "Black",
             "Capabilities":["Fly", "Fight"],
             "Action": "Flying"
            }

charecter1["Action"] = "Sitting" # Varying charecter1
charecter1["Color"] = "Red"
print(charecter1)
# Out:
# {'Name': 'Fanta', 'Color': 'Red', 'Capabilities': ['Run', 'Fight'], 'Action': 'Sitting'}

# %%
# KB : 1024 Bytes
# MB : 1024*1024 Bytes
# GB : 1024 * 1MB
# TB : 1024 * 1GB
